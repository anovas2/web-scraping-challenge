# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd


def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)
    return browser


def scrapemarsnews():
    browser = init_browser()
    marsnews = {}

    url = 'https://mars.nasa.gov/news/'
    browser.visit(url)

    html = browser.html
    soup = BeautifulSoup(html, "html.parser")

    alllistings = soup.find_all('div', class_="list_text")
    
    news_title = [x.find(class_='content_title').a.text for x in alllistings]
    news_p = [x.find(class_='article_teaser_body').text for x in alllistings]

#     print(news_title)
#     print(news_p)
    
    marsnews = pd.DataFrame({
    "news_title": news_title,
    "news_p": news_p
    })
        
    display(marsnews)
    return marsnews

# %%
scrapemarsnews()
# Out:
#                                            news_title  \
# 0       NASA Invites Students to Name Mars 2020 Rover
# 1   NASA's Mars Helicopter Attached to Mars 2020 R...
# 2   What's Mars Solar Conjunction, and Why Does It...
# 3     Scientists Explore Outback as Testbed for Mars
# 4        NASA-JPL Names 'Rolling Stones Rock' on Mars
# 5     Robotic Toolkit Added to NASA's Mars 2020 Rover
# 6   Space Samples Link NASA's Apollo 11 and Mars 2020
# 7                 Small Satellite Mission of the Year
# 8   NASA 'Optometrists' Verify Mars 2020 Rover's 2...
# 9   New Finds for Mars Rover, Seven Years After La...
# 10  MEDLI2 Installation on Mars 2020 Aeroshell Begins
# 11          NASA's Mars 2020 Rover Does Biceps Curls
# 12  Fueling of NASA's Mars 2020 Rover Power System...
# 13                   What Does a Marsquake Look Like?
# 14    Mars 2020 Rover: T-Minus One Year and Counting
# 15  NASA Racks Up Two Emmy Nominations for Mission...
# 16          Want to Colonize Mars? Aerogel Could Help
# 17                            A Rover Pit Stop at JPL
# 18            Mars 2020 Rover Gets a Super Instrument
# 19  A Neil Armstrong for Mars: Landing the Mars 20...
# 20                NASA's InSight Uncovers the 'Mole'
# 21  Mars 2020 Rover's 7-Foot-Long Robotic Arm Inst...
# 22  NASA Selects Partners for Mars 2020 'Name the ...
# 23         Curiosity's Mars Methane Mystery Continues
# 24                    Mars 2020 Rover Gets Its Wheels
# 25      The Mast Is Raised for NASA's Mars 2020 Rover
# 26   NASA's Mars 2020 Will Blaze a Trail — for Humans
# 27  Johnson-Built Device to Help Mars 2020 Rover S...
# 28               Watch NASA Build Its Next Mars Rover
# 29  NASA's Mars Helicopter Testing Enters Final Phase
# 30  InSight's Team Tries New Strategy to Help the ...
# 31            Common Questions about InSight's 'Mole'
# 32     NASA's Curiosity Mars Rover Finds a Clay Cache
# 33  NASA to Land in Mars, Pennsylvania to Celebrat...
# 34  NASA's Mars 2020 Gets a Dose of Space Here on ...
# 35  NASA Invites Public to Submit Names to Fly Abo...
# 36      NASA's MRO Completes 60,000 Trips Around Mars
# 37                Video: Fly over Mount Sharp on Mars
# 38        Why This Martian Full Moon Looks Like Candy
# 39  For InSight, Dust Cleanings Will Yield New Sci...
#
#                                                news_p
# 0   Through Nov. 1, K-12 students in the U.S. are ...
# 1   The helicopter will be first aircraft to perfo...
# 2   NASA spacecraft at Mars are going to be on the...
# 3   Australia provides a great place for NASA's Ma...
# 4   NASA's Mars InSight mission honored one of the...
# 5   The bit carousel, which lies at the heart of t...
# 6   While separated by half a century, NASA's Apol...
# 7   The first interplanetary CubeSats were recogni...
# 8   Mars 2020 rover underwent an eye exam after se...
# 9   NASA's Curiosity rover is discovering odd rock...
# 10  Hardware installed onto NASA's Mars 2020 entry...
# 11  In this time-lapse video, the robotic arm on N...
# 12  NASA gives the go-ahead to fuel the Mars 2020 ...
# 13  InSight scientists used a special "shake room"...
# 14  The launch period for NASA's next rover, Mars ...
# 15  JPL's coverage of the Mars InSight mission is ...
# 16  Researchers are studying whether a wonder mate...
# 17  Working like a finely honed machine, a team of...
# 18  With its rock-zapping laser, the SuperCam will...
# 19  NASA's newest rover will have an autopilot cal...
# 20  The lander's robotic arm has successfully remo...
# 21  The main robotic arm has been installed on NAS...
# 22  The contest for U.S. schoolchildren will open ...
# 23  The Curiosity rover’s follow-on sampling shows...
# 24  With the mobility suspension in place, the rov...
# 25  Engineers at JPL take a group selfie after att...
# 26  The next robotic Mars mission will carry techn...
# 27  NASA’s Johnson Space Center (JSC) recently bui...
# 28  A newly installed webcam offers the public a l...
# 29  NASA's Mars Helicopter flight demonstration pr...
# 30  The spacecraft's robotic arm will lift the hea...
# 31  There's a new plan to get InSight's "mole" mov...
# 32  The rover recently drilled two samples, and bo...
# 33  NASA returns to Mars, Pennsylvania Friday, May...
# 34  NASA's Mars 2020 spacecraft has completed test...
# 35  From now till Sept. 30, the public can submit ...
# 36  The orbiting spacecraft is also about to set a...
# 37  A new animation shows the region NASA's Curios...
# 38  For the first time, NASA's Mars Odyssey orbite...
# 39  Wind can be crucial to clearing dust from spac...
# {}

# %%
def jpljpg():
    browser = init_browser()
    marsnews = {}

    url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
    browser.visit(url)

    html = browser.html
    soup = BeautifulSoup(html, "html.parser")

    featured_image_url = soup.find('div', class_="carousel_items").article['style']
    
    char1 = '('
    char2 = ')'
    
    featured_image_url = featured_image_url[featured_image_url.find(char1)+1 : featured_image_url.find(char2)].replace("'", '')
    featured_image_url = f'{url}/{featured_image_url}'

    
    print(featured_image_url)

    return featured_image_url

# %%
jpljpg()
# Out:
# https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars//spaceimages/images/wallpaper/PIA14872-1920x1200.jpg
# 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars//spaceimages/images/wallpaper/PIA14872-1920x1200.jpg'
